# %%
pip install jupyter_contrib_nbextensions
# Out:
# Collecting jupyter_contrib_nbextensions
#   Downloading jupyter_contrib_nbextensions-0.7.0.tar.gz (23.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 42.1 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipython_genutils in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Collecting jupyter_contrib_core>=0.3.3 (from jupyter_contrib_nbextensions)
#   Downloading jupyter_contrib_core-0.4.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jupyter_core in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_contrib_nbextensions) (5.7.2)
# Collecting jupyter_highlight_selected_word>=0.1.1 (from jupyter_contrib_nbextensions)
#   Downloading jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl.metadata (730 bytes)
# Collecting jupyter_nbextensions_configurator>=0.4.0 (from jupyter_contrib_nbextensions)
#   Downloading jupyter_nbextensions_configurator-0.6.4-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: nbconvert>=6.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_contrib_nbextensions) (7.10.0)
# Requirement already satisfied: notebook>=6.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_contrib_nbextensions) (7.0.8)
# Requirement already satisfied: tornado in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_contrib_nbextensions) (6.4.1)
# Requirement already satisfied: traitlets>=4.1 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_contrib_nbextensions) (5.14.3)
# Requirement already satisfied: lxml in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_contrib_nbextensions) (5.2.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_contrib_core>=0.3.3->jupyter_contrib_nbextensions) (69.5.1)
# Requirement already satisfied: jupyter-server in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.14.1)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (6.0.1)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.1.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.9.2)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (23.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.15.1)
# Requirement already satisfied: tinycss2 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.2.1)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_core->jupyter_contrib_nbextensions) (3.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /opt/anaconda3/lib/python3.12/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in /opt/anaconda3/lib/python3.12/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/anaconda3/lib/python3.12/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.2.4)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.16.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: anyio>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (8.6.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.14.1)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.4)
# Requirement already satisfied: ipykernel in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.0)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (4.19.2)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.32.2)
# Requirement already satisfied: fastjsonschema in /opt/anaconda3/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.16.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.5)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in /opt/anaconda3/lib/python3.12/site-packages (from babel>=2.10->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2024.1)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-client>=7.4.4->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.9.0.post0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2024.7.4)
# Requirement already satisfied: ptyprocess in /opt/anaconda3/lib/python3.12/site-packages (from terminado>=0.8.3->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.7.0)
# Requirement already satisfied: appnope in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (8.25.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (1.6.0)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (5.9.0)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.43)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (4.8.0)
# Requirement already satisfied: fqdn in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.1)
# Requirement already satisfied: uri-template in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (24.6.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.5)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.2.3)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.2)
# Downloading jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl (11 kB)
# Downloading jupyter_nbextensions_configurator-0.6.4-py2.py3-none-any.whl (466 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 466.9/466.9 kB 29.5 MB/s eta 0:00:00
# Building wheels for collected packages: jupyter_contrib_nbextensions, jupyter_contrib_core
#   Building wheel for jupyter_contrib_nbextensions (setup.py) ... done
#   Created wheel for jupyter_contrib_nbextensions: filename=jupyter_contrib_nbextensions-0.7.0-py2.py3-none-any.whl size=23428778 sha256=85dc63fa40303514b810e8bc9e06c6b06446acbbdabaa03bda29f52d19d2d681
#   Stored in directory: /Users/amansingh/Library/Caches/pip/wheels/4d/e4/20/dd16cdbbddcfe309a4559ea16adfa75fa5c554cfd076f9dae8
#   Building wheel for jupyter_contrib_core (setup.py) ... done
#   Created wheel for jupyter_contrib_core: filename=jupyter_contrib_core-0.4.2-py2.py3-none-any.whl size=17482 sha256=15a1cfbcf42a812d349ee6d41aa0b25a187ac2edb9643e9412137dd9063a1fce
#   Stored in directory: /Users/amansingh/Library/Caches/pip/wheels/32/f9/af/259a6f50f8b89d972aa81e31808a0af14e8bfc6867fb16ed07
# Successfully built jupyter_contrib_nbextensions jupyter_contrib_core
# Installing collected packages: jupyter_highlight_selected_word, jupyter_contrib_core, jupyter_nbextensions_configurator, jupyter_contrib_nbextensions
# Successfully installed jupyter_contrib_core-0.4.2 jupyter_contrib_nbextensions-0.7.0 jupyter_highlight_selected_word-0.2.0 jupyter_nbextensions_configurator-0.6.4
# Note: you may need to restart the kernel to use updated packages.

# %%
# !jupyter contrib nbextension install --user
# Out:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/jupyter_contrib_core/notebook_compat/nbextensions.py", line 6, in <module>
#     from notebook.extensions import BaseExtensionApp
# ModuleNotFoundError: No module named 'notebook.extensions'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/jupyter_contrib_core/notebook_compat/nbextensions.py", line 10, in <module>
#     from notebook.nbextensions import BaseNBExtensionApp
# ModuleNotFoundError: No module named 'notebook.nbextensions'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/anaconda3/bin/jupyter-contrib", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/jupyter_core/application.py", line 283, in launch_instance
#     super().launch_instance(argv=argv, **kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/traitlets/config/application.py", line 1073, in launch_instance
#     app = cls.instance(**kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/traitlets/config/configurable.py", line 583, in instance
#     inst = cls(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/jupyter_contrib_core/application.py", line 27, in __init__
#     self._refresh_subcommands()
#   File "/opt/anaconda3/lib/python3.12/site-packages/jupyter_contrib_core/application.py", line 43, in _refresh_subcommands
#     get_subcommands_dict = entrypoint.load()
#                            ^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pkg_resources/__init__.py", line 2482, in load
#     return self.resolve()
#            ^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/pkg_resources/__init__.py", line 2488, in resolve
#     module = __import__(self.module_name, fromlist=['__name__'], level=0)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/jupyter_contrib_nbextensions/application.py", line 7, in <module>
#     from jupyter_contrib_core.notebook_compat.nbextensions import ArgumentConflict
#   File "/opt/anaconda3/lib/python3.12/site-packages/jupyter_contrib_core/notebook_compat/nbextensions.py", line 12, in <module>
#     from ._compat.nbextensions import BaseNBExtensionApp
#   File "/opt/anaconda3/lib/python3.12/site-packages/jupyter_contrib_core/notebook_compat/_compat/nbextensions.py", line 35, in <module>
#     from notebook.nbextensions import (
# ModuleNotFoundError: No module named 'notebook.nbextensions'

# %%
# !pip install --upgrade jupyter_contrib_nbextensions
# Out:
# Requirement already satisfied: jupyter_contrib_nbextensions in /opt/anaconda3/lib/python3.12/site-packages (0.7.0)
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-contrib-core>=0.3.3 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_contrib_nbextensions) (0.4.2)
# Requirement already satisfied: jupyter-core in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_contrib_nbextensions) (5.7.2)
# Requirement already satisfied: jupyter-highlight-selected-word>=0.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: jupyter-nbextensions-configurator>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_contrib_nbextensions) (0.6.4)
# Requirement already satisfied: nbconvert>=6.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_contrib_nbextensions) (7.10.0)
# Requirement already satisfied: notebook>=6.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_contrib_nbextensions) (7.0.8)
# Requirement already satisfied: tornado in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_contrib_nbextensions) (6.4.1)
# Requirement already satisfied: traitlets>=4.1 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_contrib_nbextensions) (5.14.3)
# Requirement already satisfied: lxml in /opt/anaconda3/lib/python3.12/site-packages (from jupyter_contrib_nbextensions) (5.2.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-contrib-core>=0.3.3->jupyter_contrib_nbextensions) (69.5.1)
# Requirement already satisfied: jupyter-server in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (2.14.1)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (6.0.1)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.1.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.9.2)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (23.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.15.1)
# Requirement already satisfied: tinycss2 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.2.1)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-core->jupyter_contrib_nbextensions) (3.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /opt/anaconda3/lib/python3.12/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in /opt/anaconda3/lib/python3.12/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/anaconda3/lib/python3.12/site-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.2.4)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.16.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: anyio>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (8.6.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (0.14.1)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.4)
# Requirement already satisfied: ipykernel in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.0)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (4.19.2)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.32.2)
# Requirement already satisfied: fastjsonschema in /opt/anaconda3/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.16.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.5)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in /opt/anaconda3/lib/python3.12/site-packages (from babel>=2.10->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2024.1)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-client>=7.4.4->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (2.9.0.post0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=6.0->jupyter_contrib_nbextensions) (2024.7.4)
# Requirement already satisfied: ptyprocess in /opt/anaconda3/lib/python3.12/site-packages (from terminado>=0.8.3->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (0.7.0)
# Requirement already satisfied: appnope in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (8.25.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (1.6.0)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (5.9.0)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.43)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (4.8.0)
# Requirement already satisfied: fqdn in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (2.1)
# Requirement already satisfied: uri-template in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (24.6.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (1.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.5)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter-nbextensions-configurator>=0.4.0->jupyter_contrib_nbextensions) (1.2.3)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.2)

# %%
# !pip install notebook==6.5.5
# Out:
# Collecting notebook==6.5.5
#   Downloading notebook-6.5.5-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from notebook==6.5.5) (3.1.4)
# Requirement already satisfied: tornado>=6.1 in /opt/anaconda3/lib/python3.12/site-packages (from notebook==6.5.5) (6.4.1)
# Collecting pyzmq<25,>=17 (from notebook==6.5.5)
#   Downloading pyzmq-24.0.1.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 8.6 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: argon2-cffi in /opt/anaconda3/lib/python3.12/site-packages (from notebook==6.5.5) (21.3.0)
# Requirement already satisfied: traitlets>=4.2.1 in /opt/anaconda3/lib/python3.12/site-packages (from notebook==6.5.5) (5.14.3)
# Requirement already satisfied: jupyter-core>=4.6.1 in /opt/anaconda3/lib/python3.12/site-packages (from notebook==6.5.5) (5.7.2)
# Collecting jupyter-client<8,>=5.3.4 (from notebook==6.5.5)
#   Downloading jupyter_client-7.4.9-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/lib/python3.12/site-packages (from notebook==6.5.5) (0.2.0)
# Requirement already satisfied: nbformat in /opt/anaconda3/lib/python3.12/site-packages (from notebook==6.5.5) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /opt/anaconda3/lib/python3.12/site-packages (from notebook==6.5.5) (7.10.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from notebook==6.5.5) (1.6.0)
# Requirement already satisfied: ipykernel in /opt/anaconda3/lib/python3.12/site-packages (from notebook==6.5.5) (6.28.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from notebook==6.5.5) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from notebook==6.5.5) (0.17.1)
# Requirement already satisfied: prometheus-client in /opt/anaconda3/lib/python3.12/site-packages (from notebook==6.5.5) (0.14.1)
# Collecting nbclassic>=0.4.7 (from notebook==6.5.5)
#   Downloading nbclassic-1.1.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: entrypoints in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-client<8,>=5.3.4->notebook==6.5.5) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-client<8,>=5.3.4->notebook==6.5.5) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-core>=4.6.1->notebook==6.5.5) (3.10.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /opt/anaconda3/lib/python3.12/site-packages (from nbclassic>=0.4.7->notebook==6.5.5) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=5->notebook==6.5.5) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=5->notebook==6.5.5) (4.1.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=5->notebook==6.5.5) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=5->notebook==6.5.5) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=5->notebook==6.5.5) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=5->notebook==6.5.5) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=5->notebook==6.5.5) (0.8.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=5->notebook==6.5.5) (23.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=5->notebook==6.5.5) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=5->notebook==6.5.5) (2.15.1)
# Requirement already satisfied: tinycss2 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=5->notebook==6.5.5) (1.2.1)
# Requirement already satisfied: fastjsonschema in /opt/anaconda3/lib/python3.12/site-packages (from nbformat->notebook==6.5.5) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /opt/anaconda3/lib/python3.12/site-packages (from nbformat->notebook==6.5.5) (4.19.2)
# Requirement already satisfied: ptyprocess in /opt/anaconda3/lib/python3.12/site-packages (from terminado>=0.8.3->notebook==6.5.5) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/lib/python3.12/site-packages (from argon2-cffi->notebook==6.5.5) (21.2.0)
# Requirement already satisfied: appnope in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->notebook==6.5.5) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->notebook==6.5.5) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->notebook==6.5.5) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->notebook==6.5.5) (8.25.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->notebook==6.5.5) (0.1.6)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel->notebook==6.5.5) (5.9.0)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=5->notebook==6.5.5) (1.16.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=5->notebook==6.5.5) (0.5.1)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->notebook==6.5.5) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->notebook==6.5.5) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->notebook==6.5.5) (3.0.43)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->notebook==6.5.5) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->notebook==6.5.5) (4.8.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->notebook==6.5.5) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->notebook==6.5.5) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->notebook==6.5.5) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->notebook==6.5.5) (0.10.6)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /opt/anaconda3/lib/python3.12/site-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook==6.5.5) (2.14.1)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook==6.5.5) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=5->notebook==6.5.5) (2.5)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook==6.5.5) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook==6.5.5) (0.8.3)
# Requirement already satisfied: anyio>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook==6.5.5) (4.2.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook==6.5.5) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook==6.5.5) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook==6.5.5) (7.4.0)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook==6.5.5) (1.8.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->notebook==6.5.5) (0.2.5)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook==6.5.5) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook==6.5.5) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook==6.5.5) (0.2.2)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook==6.5.5) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook==6.5.5) (1.3.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook==6.5.5) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook==6.5.5) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook==6.5.5) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook==6.5.5) (0.1.1)
# Requirement already satisfied: fqdn in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook==6.5.5) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook==6.5.5) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook==6.5.5) (2.1)
# Requirement already satisfied: uri-template in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook==6.5.5) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook==6.5.5) (24.6.0)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook==6.5.5) (1.2.3)
# Downloading notebook-6.5.5-py3-none-any.whl (529 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.8/529.8 kB 31.2 MB/s eta 0:00:00
# Downloading jupyter_client-7.4.9-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 14.7 MB/s eta 0:00:00
# Downloading nbclassic-1.1.0-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 40.2 MB/s eta 0:00:00 0:00:01
# Building wheels for collected packages: pyzmq
#   Building wheel for pyzmq (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for pyzmq (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [266 lines of output]
#       /private/var/folders/1q/s253407j181087kqscr2byl40000gn/T/pip-build-env-ubooc73i/overlay/lib/python3.12/site-packages/setuptools/_distutils/dist.py:268: UserWarning: Unknown distribution option: 'cffi_modules'
#         warnings.warn(msg)
#       running bdist_wheel
#       running build
#       running build_py
#       copying zmq/_typing.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq
#       copying zmq/error.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq
#       copying zmq/_future.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq
#       copying zmq/asyncio.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq
#       copying zmq/constants.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq
#       copying zmq/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq
#       copying zmq/decorators.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq
#       creating build/lib.macosx-11.1-arm64-cpython-312/zmq/green
#       copying zmq/green/device.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/green
#       copying zmq/green/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/green
#       copying zmq/green/core.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/green
#       copying zmq/green/poll.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/green
#       creating build/lib.macosx-11.1-arm64-cpython-312/zmq/green/eventloop
#       copying zmq/green/eventloop/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/green/eventloop
#       copying zmq/green/eventloop/ioloop.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/green/eventloop
#       copying zmq/green/eventloop/zmqstream.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/green/eventloop
#       creating build/lib.macosx-11.1-arm64-cpython-312/zmq/sugar
#       copying zmq/sugar/version.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/sugar
#       copying zmq/sugar/attrsettr.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/sugar
#       copying zmq/sugar/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/sugar
#       copying zmq/sugar/stopwatch.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/sugar
#       copying zmq/sugar/context.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/sugar
#       copying zmq/sugar/frame.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/sugar
#       copying zmq/sugar/tracker.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/sugar
#       copying zmq/sugar/poll.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/sugar
#       copying zmq/sugar/socket.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/sugar
#       creating build/lib.macosx-11.1-arm64-cpython-312/zmq/auth
#       copying zmq/auth/thread.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/auth
#       copying zmq/auth/certs.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/auth
#       copying zmq/auth/asyncio.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/auth
#       copying zmq/auth/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/auth
#       copying zmq/auth/ioloop.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/auth
#       copying zmq/auth/base.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/auth
#       creating build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_ioloop.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_version.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_monitor.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_security.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/conftest.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_decorators.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_etc.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_pubsub.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_auth.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_includes.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_mypy.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_future.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_zmqstream.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_message.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_cffi_backend.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_imports.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_socket.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_draft.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_asyncio.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_log.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_ssh.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_cython.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_retry_eintr.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_z85.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_error.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_reqrep.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_ext.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_multipart.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_context.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_proxy_steerable.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_device.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_pair.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_constants.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_monqueue.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_poll.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/tests/test_win32_shim.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       creating build/lib.macosx-11.1-arm64-cpython-312/zmq/utils
#       copying zmq/utils/strtypes.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/utils
#       copying zmq/utils/monitor.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/utils
#       copying zmq/utils/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/utils
#       copying zmq/utils/win32.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/utils
#       copying zmq/utils/interop.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/utils
#       copying zmq/utils/jsonapi.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/utils
#       copying zmq/utils/z85.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/utils
#       copying zmq/utils/garbage.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/utils
#       creating build/lib.macosx-11.1-arm64-cpython-312/zmq/backend
#       copying zmq/backend/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/backend
#       copying zmq/backend/select.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/backend
#       creating build/lib.macosx-11.1-arm64-cpython-312/zmq/backend/cffi
#       copying zmq/backend/cffi/_poll.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/backend/cffi
#       copying zmq/backend/cffi/error.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/backend/cffi
#       copying zmq/backend/cffi/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/backend/cffi
#       copying zmq/backend/cffi/message.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/backend/cffi
#       copying zmq/backend/cffi/context.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/backend/cffi
#       copying zmq/backend/cffi/utils.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/backend/cffi
#       copying zmq/backend/cffi/socket.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/backend/cffi
#       copying zmq/backend/cffi/devices.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/backend/cffi
#       creating build/lib.macosx-11.1-arm64-cpython-312/zmq/backend/cython
#       copying zmq/backend/cython/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/backend/cython
#       creating build/lib.macosx-11.1-arm64-cpython-312/zmq/ssh
#       copying zmq/ssh/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/ssh
#       copying zmq/ssh/tunnel.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/ssh
#       copying zmq/ssh/forward.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/ssh
#       creating build/lib.macosx-11.1-arm64-cpython-312/zmq/eventloop
#       copying zmq/eventloop/_deprecated.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/eventloop
#       copying zmq/eventloop/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/eventloop
#       copying zmq/eventloop/ioloop.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/eventloop
#       copying zmq/eventloop/future.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/eventloop
#       copying zmq/eventloop/zmqstream.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/eventloop
#       creating build/lib.macosx-11.1-arm64-cpython-312/zmq/eventloop/minitornado
#       copying zmq/eventloop/minitornado/concurrent.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/eventloop/minitornado
#       copying zmq/eventloop/minitornado/stack_context.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/eventloop/minitornado
#       copying zmq/eventloop/minitornado/log.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/eventloop/minitornado
#       copying zmq/eventloop/minitornado/util.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/eventloop/minitornado
#       copying zmq/eventloop/minitornado/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/eventloop/minitornado
#       copying zmq/eventloop/minitornado/ioloop.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/eventloop/minitornado
#       creating build/lib.macosx-11.1-arm64-cpython-312/zmq/eventloop/minitornado/platform
#       copying zmq/eventloop/minitornado/platform/interface.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/eventloop/minitornado/platform
#       copying zmq/eventloop/minitornado/platform/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/eventloop/minitornado/platform
#       copying zmq/eventloop/minitornado/platform/common.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/eventloop/minitornado/platform
#       copying zmq/eventloop/minitornado/platform/posix.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/eventloop/minitornado/platform
#       copying zmq/eventloop/minitornado/platform/windows.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/eventloop/minitornado/platform
#       copying zmq/eventloop/minitornado/platform/auto.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/eventloop/minitornado/platform
#       creating build/lib.macosx-11.1-arm64-cpython-312/zmq/log
#       copying zmq/log/handlers.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/log
#       copying zmq/log/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/log
#       copying zmq/log/__main__.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/log
#       creating build/lib.macosx-11.1-arm64-cpython-312/zmq/devices
#       copying zmq/devices/monitoredqueue.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/devices
#       copying zmq/devices/__init__.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/devices
#       copying zmq/devices/monitoredqueuedevice.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/devices
#       copying zmq/devices/proxydevice.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/devices
#       copying zmq/devices/basedevice.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/devices
#       copying zmq/devices/proxysteerabledevice.py -> build/lib.macosx-11.1-arm64-cpython-312/zmq/devices
#       copying zmq/__init__.pyi -> build/lib.macosx-11.1-arm64-cpython-312/zmq
#       copying zmq/py.typed -> build/lib.macosx-11.1-arm64-cpython-312/zmq
#       copying zmq/__init__.pxd -> build/lib.macosx-11.1-arm64-cpython-312/zmq
#       copying zmq/sugar/__init__.pyi -> build/lib.macosx-11.1-arm64-cpython-312/zmq/sugar
#       copying zmq/tests/cython_ext.pyx -> build/lib.macosx-11.1-arm64-cpython-312/zmq/tests
#       copying zmq/utils/buffers.pxd -> build/lib.macosx-11.1-arm64-cpython-312/zmq/utils
#       copying zmq/utils/getpid_compat.h -> build/lib.macosx-11.1-arm64-cpython-312/zmq/utils
#       copying zmq/utils/pyversion_compat.h -> build/lib.macosx-11.1-arm64-cpython-312/zmq/utils
#       copying zmq/utils/zmq_compat.h -> build/lib.macosx-11.1-arm64-cpython-312/zmq/utils
#       copying zmq/utils/mutex.h -> build/lib.macosx-11.1-arm64-cpython-312/zmq/utils
#       copying zmq/utils/ipcmaxlen.h -> build/lib.macosx-11.1-arm64-cpython-312/zmq/utils
#       copying zmq/utils/config.json -> build/lib.macosx-11.1-arm64-cpython-312/zmq/utils
#       copying zmq/utils/compiler.json -> build/lib.macosx-11.1-arm64-cpython-312/zmq/utils
#       copying zmq/backend/__init__.pyi -> build/lib.macosx-11.1-arm64-cpython-312/zmq/backend
#       copying zmq/backend/cffi/_cdefs.h -> build/lib.macosx-11.1-arm64-cpython-312/zmq/backend/cffi
#       copying zmq/backend/cython/message.pxd -> build/lib.macosx-11.1-arm64-cpython-312/zmq/backend/cython
#       copying zmq/backend/cython/libzmq.pxd -> build/lib.macosx-11.1-arm64-cpython-312/zmq/backend/cython
#       copying zmq/backend/cython/checkrc.pxd -> build/lib.macosx-11.1-arm64-cpython-312/zmq/backend/cython
#       copying zmq/backend/cython/__init__.pxd -> build/lib.macosx-11.1-arm64-cpython-312/zmq/backend/cython
#       copying zmq/backend/cython/context.pxd -> build/lib.macosx-11.1-arm64-cpython-312/zmq/backend/cython
#       copying zmq/backend/cython/socket.pxd -> build/lib.macosx-11.1-arm64-cpython-312/zmq/backend/cython
#       copying zmq/backend/cython/constant_enums.pxi -> build/lib.macosx-11.1-arm64-cpython-312/zmq/backend/cython
#       copying zmq/devices/monitoredqueue.pxd -> build/lib.macosx-11.1-arm64-cpython-312/zmq/devices
#       running build_ext
#       running configure
#       Using bundled libzmq
#       already have bundled/zeromq
#       already have platform.hpp
#       building 'zmq.libzmq' extension
#       creating build/temp.macosx-11.1-arm64-cpython-312/buildutils
#       creating build/temp.macosx-11.1-arm64-cpython-312/bundled
#       creating build/temp.macosx-11.1-arm64-cpython-312/bundled/zeromq
#       creating build/temp.macosx-11.1-arm64-cpython-312/bundled/zeromq/src
#       clang++ -std=c++11 -fno-strict-overflow -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -DZMQ_HAVE_CURVE=1 -DZMQ_USE_TWEETNACL=1 -DZMQ_USE_KQUEUE=1 -DZMQ_IOTHREADS_USE_KQUEUE=1 -DZMQ_POLL_BASED_ON_POLL=1 -Ibundled/zeromq/include -Ibundled -I/opt/anaconda3/include/python3.12 -c buildutils/initlibzmq.cpp -o build/temp.macosx-11.1-arm64-cpython-312/buildutils/initlibzmq.o
#       clang++ -std=c++11 -fno-strict-overflow -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -DZMQ_HAVE_CURVE=1 -DZMQ_USE_TWEETNACL=1 -DZMQ_USE_KQUEUE=1 -DZMQ_IOTHREADS_USE_KQUEUE=1 -DZMQ_POLL_BASED_ON_POLL=1 -Ibundled/zeromq/include -Ibundled -I/opt/anaconda3/include/python3.12 -c bundled/zeromq/src/address.cpp -o build/temp.macosx-11.1-arm64-cpython-312/bundled/zeromq/src/address.o
#       clang++ -std=c++11 -fno-strict-overflow -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -DZMQ_HAVE_CURVE=1 -DZMQ_USE_TWEETNACL=1 -DZMQ_USE_KQUEUE=1 -DZMQ_IOTHREADS_USE_KQUEUE=1 -DZMQ_POLL_BASED_ON_POLL=1 -Ibundled/zeromq/include -Ibundled -I/opt/anaconda3/include/python3.12 -c bundled/zeromq/src/channel.cpp -o build/temp.macosx-11.1-arm64-cpython-312/bundled/zeromq/src/channel.o
#       clang++ -std=c++11 -fno-strict-overflow -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -DZMQ_HAVE_CURVE=1 -DZMQ_USE_TWEETNACL=1 -DZMQ_USE_KQUEUE=1 -DZMQ_IOTHREADS_USE_KQUEUE=1 -DZMQ_POLL_BASED_ON_POLL=1 -Ibundled/zeromq/include -Ibundled -I/opt/anaconda3/include/python3.12 -c bundled/zeromq/src/client.cpp -o build/temp.macosx-11.1-arm64-cpython-312/bundled/zeromq/src/client.o
#       clang++ -std=c++11 -fno-strict-overflow -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -DZMQ_HAVE_CURVE=1 -DZMQ_USE_TWEETNACL=1 -DZMQ_USE_KQUEUE=1 -DZMQ_IOTHREADS_USE_KQUEUE=1 -DZMQ_POLL_BASED_ON_POLL=1 -Ibundled/zeromq/include -Ibundled -I/opt/anaconda3/include/python3.12 -c bundled/zeromq/src/clock.cpp -o build/temp.macosx-11.1-arm64-cpython-312/bundled/zeromq/src/clock.o
#       clang++ -std=c++11 -fno-strict-overflow -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -DZMQ_HAVE_CURVE=1 -DZMQ_USE_TWEETNACL=1 -DZMQ_USE_KQUEUE=1 -DZMQ_IOTHREADS_USE_KQUEUE=1 -DZMQ_POLL_BASED_ON_POLL=1 -Ibundled/zeromq/include -Ibundled -I/opt/anaconda3/include/python3.12 -c bundled/zeromq/src/ctx.cpp -o build/temp.macosx-11.1-arm64-cpython-312/bundled/zeromq/src/ctx.o
#       clang++ -std=c++11 -fno-strict-overflow -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/include -arch arm64 -DZMQ_HAVE_CURVE=1 -DZMQ_USE_TWEETNACL=1 -DZMQ_USE_KQUEUE=1 -DZMQ_IOTHREADS_USE_KQUEUE=1 -DZMQ_POLL_BASED_ON_POLL=1 -Ibundled/zeromq/include -Ibundled -I/opt/anaconda3/include/python3.12 -c bundled/zeromq/src/curve_client.cpp -o build/temp.macosx-11.1-arm64-cpython-312/bundled/zeromq/src/curve_client.o
#       In file included from bundled/zeromq/src/curve_client.cpp:35:
#       In file included from bundled/zeromq/src/msg.hpp:40:
#       In file included from bundled/zeromq/src/metadata.hpp:33:
#       In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/map:2529:
#       In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/functional:526:
#       In file included from /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/__functional/boyer_moore_searcher.h:27:
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/vector:407:5: error: static assertion failed due to requirement 'is_same<zmq::secure_allocator_t<unsigned char>, std::allocator<unsigned char>>::value': [allocator.requirements] states that rebinding an allocator to the same type should result in the original allocator
#           static_assert(is_same<allocator_type, __rebind_alloc<__alloc_traits, value_type> >::value,
#           ^             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       bundled/zeromq/src/curve_client_tools.hpp:64:60: note: in instantiation of template class 'std::vector<unsigned char, zmq::secure_allocator_t<unsigned char>>' requested here
#               std::vector<uint8_t, secure_allocator_t<uint8_t> > hello_plaintext (
#                                                                  ^
#       bundled/zeromq/src/curve_client_tools.hpp:110:60: error: no matching constructor for initialization of 'std::vector<uint8_t, secure_allocator_t<uint8_t>>' (aka 'vector<unsigned char, secure_allocator_t<unsigned char>>')
#               std::vector<uint8_t, secure_allocator_t<uint8_t> > welcome_plaintext (
#                                                                  ^
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/vector:383:28: note: candidate constructor (the implicit copy constructor) not viable: no known conversion from 'int' to 'const std::vector<unsigned char, zmq::secure_allocator_t<unsigned char>>' for 1st argument
#       class _LIBCPP_TEMPLATE_VIS vector
#                                  ^
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/vector:383:28: note: candidate constructor (the implicit move constructor) not viable: no known conversion from 'int' to 'std::vector<unsigned char, zmq::secure_allocator_t<unsigned char>>' for 1st argument
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/vector:383:28: note: candidate constructor (the implicit default constructor) not viable: requires 0 arguments, but 1 was provided
#       In file included from bundled/zeromq/src/curve_client.cpp:38:
#       In file included from bundled/zeromq/src/curve_client.hpp:37:
#       bundled/zeromq/src/curve_client_tools.hpp:121:53: error: type 'std::vector<uint8_t, secure_allocator_t<uint8_t>>' (aka 'vector<unsigned char, secure_allocator_t<unsigned char>>') does not provide a subscript operator
#               int rc = crypto_box_open (&welcome_plaintext[0], welcome_box,
#                                          ~~~~~~~~~~~~~~~~~^~
#       bundled/zeromq/src/curve_client_tools.hpp:129:47: error: type 'std::vector<uint8_t, secure_allocator_t<uint8_t>>' (aka 'vector<unsigned char, secure_allocator_t<unsigned char>>') does not provide a subscript operator
#               memcpy (cn_server_, &welcome_plaintext[crypto_box_ZEROBYTES], 32);
#                                    ~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~
#       bundled/zeromq/src/curve_client_tools.hpp:130:47: error: type 'std::vector<uint8_t, secure_allocator_t<uint8_t>>' (aka 'vector<unsigned char, secure_allocator_t<unsigned char>>') does not provide a subscript operator
#               memcpy (cn_cookie_, &welcome_plaintext[crypto_box_ZEROBYTES + 32],
#                                    ~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~
#       bundled/zeromq/src/curve_client_tools.hpp:154:60: error: no matching constructor for initialization of 'std::vector<uint8_t, secure_allocator_t<uint8_t>>' (aka 'vector<unsigned char, secure_allocator_t<unsigned char>>')
#               std::vector<uint8_t, secure_allocator_t<uint8_t> > vouch_plaintext (
#                                                                  ^
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/vector:383:28: note: candidate constructor (the implicit copy constructor) not viable: no known conversion from 'int' to 'const std::vector<unsigned char, zmq::secure_allocator_t<unsigned char>>' for 1st argument
#       class _LIBCPP_TEMPLATE_VIS vector
#                                  ^
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/vector:383:28: note: candidate constructor (the implicit move constructor) not viable: no known conversion from 'int' to 'std::vector<unsigned char, zmq::secure_allocator_t<unsigned char>>' for 1st argument
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/vector:383:28: note: candidate constructor (the implicit default constructor) not viable: requires 0 arguments, but 1 was provided
#       In file included from bundled/zeromq/src/curve_client.cpp:38:
#       In file included from bundled/zeromq/src/curve_client.hpp:37:
#       bundled/zeromq/src/curve_client_tools.hpp:159:36: error: no member named 'begin' in 'std::vector<unsigned char, zmq::secure_allocator_t<unsigned char>>'
#               std::fill (vouch_plaintext.begin (),
#                          ~~~~~~~~~~~~~~~ ^
#       bundled/zeromq/src/curve_client_tools.hpp:160:36: error: no member named 'begin' in 'std::vector<unsigned char, zmq::secure_allocator_t<unsigned char>>'
#                          vouch_plaintext.begin () + crypto_box_ZEROBYTES, 0);
#                          ~~~~~~~~~~~~~~~ ^
#       bundled/zeromq/src/curve_client_tools.hpp:161:33: error: type 'std::vector<uint8_t, secure_allocator_t<uint8_t>>' (aka 'vector<unsigned char, secure_allocator_t<unsigned char>>') does not provide a subscript operator
#               memcpy (&vouch_plaintext[crypto_box_ZEROBYTES], cn_public_, 32);
#                        ~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~
#       bundled/zeromq/src/curve_client_tools.hpp:162:33: error: type 'std::vector<uint8_t, secure_allocator_t<uint8_t>>' (aka 'vector<unsigned char, secure_allocator_t<unsigned char>>') does not provide a subscript operator
#               memcpy (&vouch_plaintext[crypto_box_ZEROBYTES + 32], server_key_, 32);
#                        ~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~
#       bundled/zeromq/src/curve_client_tools.hpp:169:50: error: type 'std::vector<uint8_t, secure_allocator_t<uint8_t>>' (aka 'vector<unsigned char, secure_allocator_t<unsigned char>>') does not provide a subscript operator
#                 crypto_box (vouch_box, &vouch_plaintext[0], vouch_plaintext.size (),
#                                         ~~~~~~~~~~~~~~~^~
#       bundled/zeromq/src/curve_client_tools.hpp:169:71: error: no member named 'size' in 'std::vector<unsigned char, zmq::secure_allocator_t<unsigned char>>'
#                 crypto_box (vouch_box, &vouch_plaintext[0], vouch_plaintext.size (),
#                                                             ~~~~~~~~~~~~~~~ ^
#       bundled/zeromq/src/curve_client_tools.hpp:177:60: error: no matching constructor for initialization of 'std::vector<uint8_t, secure_allocator_t<uint8_t>>' (aka 'vector<unsigned char, secure_allocator_t<unsigned char>>')
#               std::vector<uint8_t, secure_allocator_t<uint8_t> > initiate_plaintext (
#                                                                  ^
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/vector:383:28: note: candidate constructor (the implicit copy constructor) not viable: no known conversion from 'size_t' (aka 'unsigned long') to 'const std::vector<unsigned char, zmq::secure_allocator_t<unsigned char>>' for 1st argument
#       class _LIBCPP_TEMPLATE_VIS vector
#                                  ^
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/vector:383:28: note: candidate constructor (the implicit move constructor) not viable: no known conversion from 'size_t' (aka 'unsigned long') to 'std::vector<unsigned char, zmq::secure_allocator_t<unsigned char>>' for 1st argument
#       /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk/usr/include/c++/v1/vector:383:28: note: candidate constructor (the implicit default constructor) not viable: requires 0 arguments, but 1 was provided
#       In file included from bundled/zeromq/src/curve_client.cpp:38:
#       In file included from bundled/zeromq/src/curve_client.hpp:37:
#       bundled/zeromq/src/curve_client_tools.hpp:181:39: error: no member named 'begin' in 'std::vector<unsigned char, zmq::secure_allocator_t<unsigned char>>'
#               std::fill (initiate_plaintext.begin (),
#                          ~~~~~~~~~~~~~~~~~~ ^
#       bundled/zeromq/src/curve_client_tools.hpp:182:39: error: no member named 'begin' in 'std::vector<unsigned char, zmq::secure_allocator_t<unsigned char>>'
#                          initiate_plaintext.begin () + crypto_box_ZEROBYTES, 0);
#                          ~~~~~~~~~~~~~~~~~~ ^
#       bundled/zeromq/src/curve_client_tools.hpp:183:36: error: type 'std::vector<uint8_t, secure_allocator_t<uint8_t>>' (aka 'vector<unsigned char, secure_allocator_t<unsigned char>>') does not provide a subscript operator
#               memcpy (&initiate_plaintext[crypto_box_ZEROBYTES], public_key_, 32);
#                        ~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~
#       bundled/zeromq/src/curve_client_tools.hpp:184:36: error: type 'std::vector<uint8_t, secure_allocator_t<uint8_t>>' (aka 'vector<unsigned char, secure_allocator_t<unsigned char>>') does not provide a subscript operator
#               memcpy (&initiate_plaintext[crypto_box_ZEROBYTES + 32], vouch_nonce + 8,
#                        ~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~
#       bundled/zeromq/src/curve_client_tools.hpp:186:36: error: type 'std::vector<uint8_t, secure_allocator_t<uint8_t>>' (aka 'vector<unsigned char, secure_allocator_t<unsigned char>>') does not provide a subscript operator
#               memcpy (&initiate_plaintext[crypto_box_ZEROBYTES + 48],
#                        ~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~
#       bundled/zeromq/src/curve_client_tools.hpp:189:40: error: type 'std::vector<uint8_t, secure_allocator_t<uint8_t>>' (aka 'vector<unsigned char, secure_allocator_t<unsigned char>>') does not provide a subscript operator
#                   memcpy (&initiate_plaintext[crypto_box_ZEROBYTES + 48 + 80],
#                            ~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#       fatal error: too many errors emitted, stopping now [-ferror-limit=]
#       20 errors generated.
#       ************************************************
#       ************************************************
#       error: command '/usr/bin/clang++' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pyzmq
# Failed to build pyzmq
# ERROR: Could not build wheels for pyzmq, which is required to install pyproject.toml-based projects
